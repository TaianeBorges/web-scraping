# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
html = requests.get("https://www.climatempo.com.br/previsao-do-tempo/cidade/321/riodejaneiro-rj").content

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head lang="pt-br">
#   <title>
#    Previsão do tempo para hoje em Rio de Janeiro - RJ | Climatempo
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="f-v1CUADcZO9RTlI5wOpt11LsuNyyqWC6zHgEG43hQA" name="google-site-verification">
#    <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#    <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#    <meta content="no-cache, no-store" http-equiv="Cache-Control"/>
#    <meta content="no-cache, no-store" http-equiv="Pragma"/>
#    <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0" name="viewport"/>
#    <meta content="Climatempo" name="author"/>
#    <meta content="© Climatempo" name="copyright"/>
#    <meta content="https://www.climatempo.com.br/previsao-do-tempo/cidade/321/riodejaneiro-rj" name="url"/>
# ...

# %%
notice = soup.find("a",class_="_flex _align-center _margin-b-15")

# %%
print(notice)
# Out:
# <a class="_flex _align-center _margin-b-15" href="/noticia/2021/02/18/chuva-de-zcas-na-regiao-sudeste-8142" title="Previsão de muita chuva no Sudeste">
# <figure>
# <img alt="Previsão de muita chuva no Sudeste" class="lazyload" data-src="https://imagens.climatempo.com.br/climapress/galeria/2021/02/248x248_ce29039cd7578e0c0983b5dcb3a245b7.jpg"/>
# </figure>
# <p class="title -gray-dark-2">Previsão de muita chuva no Sudeste</p>
# </a>
